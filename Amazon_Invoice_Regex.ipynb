# %% [markdown]
# # Reading text from pdf file

# %%
# !pip install pytesseract
# !apt-get install tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 31 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (10.4 MB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 121671 files and directories currently installed.)
# ...

# %%
# !pip install pdf2image

# %%
# !apt-get install -y poppler-utils
# !pip install pdf2image
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 31 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.3 [186 kB]
# Fetched 186 kB in 0s (718 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 121718 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.3_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.3) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.3) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...

# %%
from pdf2image import convert_from_path

# Specify your PDF file path
pdf_file_path = '/content/invoice (2).pdf'

# Convert PDF to images
images = convert_from_path(pdf_file_path)

for i, image in enumerate(images):
    image.save(f'invoice{i + 1}.jpg', 'JPEG')

# %%
import cv2
import pytesseract
import numpy as np

for i, image in enumerate(images):
    image.save(f'invoice_page_{i + 1}.jpg', 'JPEG')
    image_np = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
    gray_image = cv2.cvtColor(image_np, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray_image)
print(text)
# Out:
# amazon.in
#
# Sold By:
#
# Appario Retail Private Ltd
#
# * Building No. 5, BGR Warehousing Complex,
# Near Shiv Sagar Hotel, Village Vahuli, Bhiwandi,
# Thane
#
# BHIWANDI, MAHARASHTRA, 421302
#
# IN
#
# PAN No: AALCA0171E
# GST Registration No: 27AALCA0171E1ZZ
#
# Order Number: 171-9748116-9992327
# Order Date: 09.11.2023
#
# Tax Invoice/Bill of Supply/Cash Memo
# (Original for Recipient)
#
# Billing Address :
#
# Nataline
#
# Lifeline Multispeciality Hospital private hospital,
# Sainath Rd, Near Bata Showroom, Daruwala
# Compound
#
# Mumbai, MAHARASHTRA, 400064
#
# IN
#
# State/UT Code: 27
#
# Shipping Address :
#
# Nataline
#
# Nataline
#
# Lifeline Multispeciality Hospital private hospital,
# Sainath Rd, Near Bata Showroom, Daruwala
# Compound
#
# Mumbai, MAHARASHTRA, 400064
#
# IN
#
# State/UT Code: 27
#
# Place of supply: MAHARASHTRA
#
# Place of delivery: MAHARASHTRA
#
# Invoice Number : BOM7-2196119
# Invoice Details : MH-BOM7-1034-2324
# Invoice Date : 09.11.2023
#
#
#
# ...

# %% [markdown]
# # Segregating the data

# %% [markdown]
# ## Order Details

# %%
import pandas as pd
import re

# %%
sold_by_values = []

        # Find all occurrences of 'Sold By' on the current page
start_positions = [m.start() for m in re.finditer('Sold By', text)]

        # Loop through each occurrence on the current page
for start in start_positions:
            end = text.find('IN',start)
            sold = text[start:end+2].replace('\n', ' ').split(':', 1)[1].strip()
            sold_by_values.append(sold)

    # Check if any 'Sold By' values were found
if sold_by_values:
        # Create a DataFrame with all 'Sold By' values
        df1 = pd.DataFrame({'Sold By': sold_by_values})
        print(df1)
else:
        print("No 'Sold By' found in the text.")
df1
# Out:
#                                              Sold By
# 0  Appario Retail Private Ltd  * Building No. 5, ...
#                                              Sold By
# 0  Appario Retail Private Ltd  * Building No. 5, ...

# %%
sold_to_values = []

        # Find all occurrences of 'Sold By' on the current page
start_positions = [m.start() for m in re.finditer('Billing Address :', text)]

        # Loop through each occurrence on the current page
for start in start_positions:
            end = text.find('IN',start)
            sold_to = text[start:end+2].replace('\n', ' ').split(':', 1)[1].strip()
            sold_to_values.append(sold_to)

    # Check if any 'Sold to' values were found
if sold_to_values:
        # Create a DataFrame with all 'Sold By' values
        df2 = pd.DataFrame({'Sold To': sold_to_values})
        print(df2)
else:
        print("No 'Sold To' found in the text.")
df2
# Out:
#                                              Sold To
# 0  Nataline  Lifeline Multispeciality Hospital pr...
#                                              Sold To
# 0  Nataline  Lifeline Multispeciality Hospital pr...

# %%
ship_add = []

start_positions = [m.start() for m in re.finditer('Shipping Address :', text)]


for start in start_positions:
            end = text.find('IN',start)
            ship= text[start:end+2].replace('\n', ' ').split(':', 1)[1].strip()
            ship_add.append(ship)


if ship_add:

        df3 = pd.DataFrame({'Shipping Address': ship_add})
        print(df3)
else:
        print("No 'Shipping Address' found in the text.")
df3
# Out:
#                                     Shipping Address
# 0  Nataline  Nataline  Lifeline Multispeciality H...
#                                     Shipping Address
# 0  Nataline  Nataline  Lifeline Multispeciality H...

# %%
ID_list = []

for i, image in enumerate(images):
    # Check if 'Order Number:' is in the text
    if 'Order Number:' in text:
        column_head = 'Order ID'
        pattern = r'\d{3}-\d{7}-\d{7}'
        matches = re.findall(pattern, text)

        # Collect order IDs in a list for each page
        ID_list.extend(matches)

# Create a DataFrame if order IDs are found
if ID_list:
    df4 = pd.DataFrame({column_head: ID_list})
    print(df4)
else:
    print("Order ID not found in the text.")
# Out:
#               Order ID
# 0  171-9748116-9992327

# %%
dates_list_od = []

for i, image in enumerate(images):
    # Check if 'Order Date' is in the text
    if 'Order Date' in text:
        column_head = 'Order Date'
        pattern = r'Order Date: (\d{2}.\d{2}.\d{4})'  # Assuming the date format is MM.DD.YYYY
        matches = re.findall(pattern, text)

        # Collect dates in a list for each page
        dates_list_od.extend(matches)

# Create a DataFrame
df5 = pd.DataFrame({'Order Date': dates_list_od})

if not df5.empty:
    print(df5)
else:
    print("Order Date not found in the text.")
# Out:
#    Order Date
# 0  09.11.2023

# %%
In_id = []

for i, image in enumerate(images):
    # Check if 'Invoice Numbe' is in the text
    if 'Invoice Number : ' in text:
        column_head = 'Invoice Number'
        pattern = r'Invoice Number : ([A-Z0-9]+-[A-Z0-9-]+)'
        matches = re.findall(pattern, text)

        # Collect dates in a list for each page
        In_id.extend(matches)

# Create a DataFrame
df6 = pd.DataFrame({'Invoice Number': In_id})

if not df6.empty:
    print(df6)
else:
    print("Invoice Number not found in the text.")
# Out:
#   Invoice Number
# 0   BOM7-2196119

# %%
dates_list = []

for i, image in enumerate(images):
    # Check if 'Invoice Date' is in the text
    if 'Invoice Date' in text:
        column_head = 'Invoice Date'
        pattern = r'Invoice Date : (\d{2}.\d{2}.\d{4})'  # Assuming the date format is MM.DD.YYYY
        matches = re.findall(pattern, text)

        # Collect dates in a list for each page
        dates_list.extend(matches)

# Create a DataFrame
df7 = pd.DataFrame({'Invoice Date': dates_list})

print(df7)
# Out:
#   Invoice Date
# 0   09.11.2023

# %%
In_d = []

for i, image in enumerate(images):
    # Check if 'Invoice Details' is in the text
    if 'Invoice Details : ' in text:
        column_head = 'Invoice Details : '
        pattern = r'Invoice Details : ([A-Z]{2}-[A-Z0-9]+-\d+-\d+)'
        matches = re.findall(pattern, text)

        # Collect details in a list for each page
        In_d.extend(matches)

# Create a DataFrame
df8 = pd.DataFrame({'Invoice Details': In_d})

if not df8.empty:
    print(df8)
else:
    print("Invoice Details not found in the text.")
# Out:
#      Invoice Details
# 0  MH-BOM7-1034-2324

# %%
payment_methods = [
    "Credit Cards",
    "Debit Cards",
    "Net Banking",
    "Amazon Pay Balance",
    "EMI",
    "UPI",
    "Cash on Delivery (COD)"
]
all_found_payments = []
for i, image in enumerate(images):
    found_payments = []

    for payment in payment_methods:
        if payment.lower() in text.lower():
            found_payments.append(payment)

    all_found_payments.extend(found_payments)

if all_found_payments:
    column_head = 'Payment method'
    df9 = pd.DataFrame({column_head: all_found_payments})
    print(df9)
else:
    print("No payment method found in the text.")
# Out:
#   Payment method
# 0            UPI

# %%
GST_list = []
for i, image in enumerate(images):
    # Check if 'GST' is in the text
    if 'GST' in text:
        pattern = r'GST Registration No: (\d{2}[A-Z]{5}\d{4}[A-Z]{1}\d{1}[A-Z]{1})'
        matches = re.findall(pattern, text)

        # Collect GSTIN in a list for each page
        GST_list.extend(matches)

# Create a DataFrame
df10 = pd.DataFrame({'GST': GST_list})

if not df10.empty:
    print(df10)
else:
    print("No GST found in the text.")
# Out:
#               GST
# 0  27AALCA0171E1Z

# %%
PAN_list = []
for i, image in enumerate(images):
    # Check if 'PAN' is in the text
    if 'PAN' in text:
        column_head = 'PAN'
        pattern = r'PAN No: ([A-Z]{5}[0-9]{4}[A-Z])'
        matches = re.findall(pattern, text)

        # Collect PAN numbers in a list for each page
        PAN_list.extend(matches)

# Create a DataFrame if PAN values are found
if PAN_list:
    df11 = pd.DataFrame({column_head: PAN_list})
    print(df11)
else:
    print("No PAN found in the text.")
# Out:
#           PAN
# 0  AALCA0171E

# %%
s_code = []

for i, image in enumerate(images):
    # Check if 'State/UT Code:' is in the text
    if 'State/UT Code: ' in text:
        column_head = 'State/UT Code:'
        pattern = r'State/UT Code:\s*(\d+)'
        matches = re.findall(pattern, text)

        # Collect dates in a list for each page
        s_code.extend(matches)

# Create a DataFrame
df12 = pd.DataFrame({'State/UT Code': s_code})

if not df12.empty:
    print(df12)
else:
    print("State/UT Code not found in the text.")
# Out:
#   State/UT Code
# 0            27
# 1            27

# %%
order_details = pd.merge(df1, df2, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df3, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df4, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df5, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df6, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df7, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df8, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df9, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df10, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df11, how='outer', left_index=True, right_index=True)
order_details = pd.merge(order_details, df12, how='outer', left_index=True, right_index=True)
order_details=order_details.dropna()
order_details
# Out:
#                                              Sold By  \
# 0  Appario Retail Private Ltd  * Building No. 5, ...
#
#                                              Sold To  \
# 0  Nataline  Lifeline Multispeciality Hospital pr...
#
#                                     Shipping Address             Order ID  \
# 0  Nataline  Nataline  Lifeline Multispeciality H...  171-9748116-9992327
#
#    Order Date Invoice Number Invoice Date    Invoice Details Payment method  \
# 0  09.11.2023   BOM7-2196119   09.11.2023  MH-BOM7-1034-2324            UPI
#
#               GST         PAN State/UT Code
# 0  27AALCA0171E1Z  AALCA0171E            27

# %% [markdown]
# # Extracting the product description in the tabel using camelot

# %%
# !apt-get install -y ghostscript
# !pip install camelot-py
# !pip install ghostscript
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 libgs9 libgs9-common libidn12 libijs-0.35
#   libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9 libgs9-common libidn12
#   libijs-0.35 libjbig2dec0 poppler-data
# 0 upgraded, 10 newly installed, 0 to remove and 31 not upgraded.
# Need to get 16.7 MB of archives.
# After this operation, 63.0 MB of additional disk space will be used.
# ...

# %%
import camelot

#pdf_path = '/content/amazon.pdf'

tables = camelot.read_pdf(pdf_file_path, flavor='lattice', pages='all')

# Display remaining tables
for i, table in enumerate(tables):
    print(f"Table {i + 1}:\n{table.df}\n")
table.df
# Out:
# Table 1:
#                                                    0  \
# 0                                            Sl.\nNo
# 1                                                  1
# 2                                             TOTAL:
# 3                 Amount in Words:\nNinety-nine only
# 4  For Appario Retail Private Ltd:\nAuthorized Si...
#
#                                                    1            2    3  \
# 0                                        Description  Unit\nPrice  Qty
# 1  AirCase Tizum Usb To Lightning 1.2M Charging C...       ₹83.90    1
# 2
# 3
# 4
#
#              4          5                 6             7              8
# 0  Net\nAmount  Tax\nRate         Tax\nType   Tax\nAmount  Total\nAmount
# 1       ₹83.90             9% CGST\n9% SGST  ₹7.55\n₹7.55         ₹99.00
# 2                                                          ₹15.10 ₹99.00
# 3
# 4
#                                                    0  \
# ...

# %%
start = 'S'
end = 'TOTAL:'

extracted_tables = []

for i, table in enumerate(tables):
    # Finding the index of the row containing the start keyword
    start_indices = table.df.index[table.df.apply(lambda row: start in ' '.join(map(str, row)), axis=1)].tolist()

    if start_indices:
        start_index = start_indices[0]

        # Finding the index of the row containing the end keyword
        end_indices = table.df.index[table.df.apply(lambda row: end in ' '.join(map(str, row)), axis=1)].tolist()

        if end_indices:
            end_index = end_indices[0]

            # Extract rows between the start and the end
            extracted_row = table.df.loc[start_index:end_index - 1]

            # Make the first row as column headers
            extracted_row.columns = extracted_row.iloc[0]

            # Append the extracted DataFrame to the list
            extracted_tables.append(extracted_row.iloc[1:].reset_index(drop=True))

            # Display the extracted row
            print(f"Table {i + 1}, Extracted Row:\n{extracted_row}\n")
        else:
            print(f"Table {i + 1}, End keyword '{end}' not found.")
    else:
        print(f"Table {i + 1}, Start keyword '{start}' not found.")

# Display the list of extracted DataFrames
for i, extracted_table in enumerate(extracted_tables):
    print(f"Extracted Table {i + 1}:\n{extracted_table}\n")
extracted_table
# Out:
# Table 1, Extracted Row:
# 0  Sl.\nNo                                        Description  Unit\nPrice  \
# 0  Sl.\nNo                                        Description  Unit\nPrice
# 1        1  AirCase Tizum Usb To Lightning 1.2M Charging C...       ₹83.90
#
# 0  Qty  Net\nAmount  Tax\nRate         Tax\nType   Tax\nAmount  Total\nAmount
# 0  Qty  Net\nAmount  Tax\nRate         Tax\nType   Tax\nAmount  Total\nAmount
# 1    1       ₹83.90             9% CGST\n9% SGST  ₹7.55\n₹7.55         ₹99.00
#
# Extracted Table 1:
# 0 Sl.\nNo                                        Description Unit\nPrice Qty  \
# 0       1  AirCase Tizum Usb To Lightning 1.2M Charging C...      ₹83.90   1
#
# 0 Net\nAmount Tax\nRate         Tax\nType   Tax\nAmount Total\nAmount
# 0      ₹83.90            9% CGST\n9% SGST  ₹7.55\n₹7.55        ₹99.00
# 0 Sl.\nNo                                        Description Unit\nPrice Qty  \
# 0       1  AirCase Tizum Usb To Lightning 1.2M Charging C...      ₹83.90   1
#
# ...

# %% [markdown]
# # Exporting to excel

# %%
# !pip install xlsxwriter
excel_file_path = 'Amazon_Invoice_Regex.xlsx'

with pd.ExcelWriter(excel_file_path, engine='xlsxwriter') as writer:
    # Write each DataFrame to a different sheet
    order_details.to_excel(writer, sheet_name='order details', index=False)
    for i,tables in enumerate(extracted_tables):
      invoice_number = df6.iloc[i]['Invoice Number']
      extracted_table['Invoice Number'] = invoice_number
      extracted_table.set_index('Invoice Number', inplace=True)
      sheet_name = f'Invoice {i + 1}'
      extracted_table.to_excel(writer, sheet_name=sheet_name, index=True)

    print('success')
# Out:
# ...
# success
